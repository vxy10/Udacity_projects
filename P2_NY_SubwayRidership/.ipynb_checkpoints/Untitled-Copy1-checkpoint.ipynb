# %%
import pandas as pd
import numpy as np
# %pylab inline

## READING data
path = '~/Desktop/1st_Kaggle/Rossman/train.csv'
data = pd.read_csv(path)
path_store = '~/Desktop/1st_Kaggle/Rossman/store.csv'
data_store = pd.read_csv(path_store)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Out:
# <bound method DataFrame.head of       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a                 1270
# 1         2         a          a                  570
# 2         3         a          a                14130
# 3         4         c          c                  620
# 4         5         a          a                29910
# 5         6         a          a                  310
# 6         7         a          c                24000
# 7         8         a          a                 7520
# 8         9         a          c                 2030
# 9        10         a          a                 3160
# 10       11         a          c                  960
# 11       12         a          c                 1070
# 12       13         d          a                  310
# 13       14         a          a                 1300
# 14       15         d          c                 4110
# 15       16         a          c                 3270
# ...
